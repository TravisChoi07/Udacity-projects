# %%
#   导入语句。
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# np.set_printoptions(suppress=True,threshold=np.nan)
#提出问题：你应该在你的调查里分析至少一个因变量和三个自变量。每年最受欢迎的电影类别是哪些？票房高的电影有哪些特点？
#预算，人员（演员、导演）、类别、上映月份，与净利润的关系 
#1，预算与净利润之间有什么关系？（预算与净利润之间的关系比较，散点图，计算相关性，必要时画出其回归线）
#2，top10的演员是谁，各种电影类别对应的票房？（每个演员、导演、类别对应净利润的平均值之间比较，画bar图）  
#3，上映月份与净利润有何关系？（画出对应每个月份利润平均值，进行比较，用bar图）

# %%
df = pd.read_csv('tmdb-movies.csv')
df.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.
#
#        ...                                                overview runtime  \
# 0      ...       Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df = df.drop(['id','imdb_id','revenue','popularity','homepage','tagline','overview','release_year'],axis=1)
df.head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-8a2539191b74> in <module>
# ----> 1 df = df.drop(['id','imdb_id','revenue','popularity','homepage','tagline','overview','release_year'],axis=1)
#       2 df.head(1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
df['profit'] = df['revenue_adj'] - df['budget_adj']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'revenue_adj'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-2ac2c9c11bdb> in <module>
# ...

# %%
df.head(1)
# Out:
#   original_title               cast       director                 keywords  \
# 0        Ronaldo  Cristiano Ronaldo  Anthony Wonke  biography|soccer player
#
#    runtime       genres                               production_companies  \
# 0        0  Documentary  On The Corner Films|We Came, We Saw, We Conque...
#
#   release_date  vote_count  vote_average  profit month
# 0      11/9/15          80           6.5     0.0    11

# %%
df = df.drop(['budget_adj','revenue_adj'], axis =1)

# %%
df.head(1)
# Out:
#    original_title                                               cast  \
# 0  Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average        profit
# 0           6.5  1.254446e+09

# %%
df['cast'].iloc[0].count('|')
# Out:
# 4

# %%
df['cast'].shape
# Out:
# (10866,)

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()

# %%
split_columns = ['cast','genres']

# %%
total_rows = df['cast'].shape[0]

# %%
#计算演员一栏中，每个元素里还有几个”|“
cast_counts = []
for i in range(total_rows):
    num_1 = df['cast'].astype(str).iloc[i].count('|')
    cast_counts.append(num_1)

# %%
set(cast_counts)
# Out:
# {0, 1, 2, 3, 4}

# %%
cast_counts.count(4)
# Out:
# 10134

# %%
df.isnull().sum()
# Out:
# original_title             0
# cast                      76
# director                  44
# keywords                1493
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# profit                     0
# dtype: int64

# %%
df = df.fillna('')

# %%
df['cast_counts'] = cast_counts  #添加一列cast_counts，表示cast中有几个|

# %%
df_ctn0 = df.query('cast_counts == 0')
df_plus0 = df_ctn0

# %%
df_ctn1 = df.query('cast_counts == 1')
df_ctn11 = df_ctn1.copy()
df_ctn12 = df_ctn1.copy()

# %%
df_ctn11['cast'] = df_ctn11['cast'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn12['cast'] = df_ctn12['cast'].astype(str).apply(lambda x: x.split('|')[1])
df_plus1 =df_ctn11.append(df_ctn12)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-acabcb11683a> in <module>
#       1 df_ctn11['cast'] = df_ctn11['cast'].astype(str).apply(lambda x: x.split('|')[0])
# ----> 2 df_ctn12['cast'] = df_ctn12['cast'].astype(str).apply(lambda x: x.split('|')[1])
#       3 df_plus1 =df_ctn11.append(df_ctn12)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-52-acabcb11683a> in <lambda>(x)
# ...

# %%
df_ctn2 = df.query('cast_counts == 2')
df_ctn21 = df_ctn2.copy()
df_ctn22 = df_ctn2.copy()
df_ctn23 = df_ctn2.copy()
df_ctn21['cast'] = df_ctn21['cast'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn22['cast'] = df_ctn22['cast'].astype(str).apply(lambda x: x.split('|')[1])
df_ctn23['cast'] = df_ctn23['cast'].astype(str).apply(lambda x: x.split('|')[2])
df_plus2 =df_ctn21.append(df_ctn22).append(df_ctn23)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-981c11a64a86> in <module>
#       4 df_ctn23 = df_ctn2.copy()
#       5 df_ctn21['cast'] = df_ctn21['cast'].astype(str).apply(lambda x: x.split('|')[0])
# ----> 6 df_ctn22['cast'] = df_ctn22['cast'].astype(str).apply(lambda x: x.split('|')[1])
#       7 df_ctn23['cast'] = df_ctn23['cast'].astype(str).apply(lambda x: x.split('|')[2])
#       8 df_plus2 =df_ctn21.append(df_ctn22).append(df_ctn23)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# ...

# %%
df_ctn3 = df.query('cast_counts == 3')
df_ctn31 = df_ctn3.copy()
df_ctn32 = df_ctn3.copy()
df_ctn33 = df_ctn3.copy()
df_ctn34 = df_ctn3.copy()
df_ctn31['cast'] = df_ctn31['cast'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn32['cast'] = df_ctn32['cast'].astype(str).apply(lambda x: x.split('|')[1])
df_ctn33['cast'] = df_ctn33['cast'].astype(str).apply(lambda x: x.split('|')[2])
df_ctn34['cast'] = df_ctn34['cast'].astype(str).apply(lambda x: x.split('|')[3])
df_plus3 =df_ctn31.append(df_ctn32).append(df_ctn33).append(df_ctn34)

# %%
df_ctn4 = df.query('cast_counts == 4')
df_ctn41 = df_ctn4.copy()
df_ctn42 = df_ctn4.copy()
df_ctn43 = df_ctn4.copy()
df_ctn44 = df_ctn4.copy()
df_ctn45 = df_ctn4.copy()
df_ctn41['cast'] = df_ctn41['cast'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn42['cast'] = df_ctn42['cast'].astype(str).apply(lambda x: x.split('|')[1])
df_ctn43['cast'] = df_ctn43['cast'].astype(str).apply(lambda x: x.split('|')[2])
df_ctn44['cast'] = df_ctn44['cast'].astype(str).apply(lambda x: x.split('|')[3])
df_ctn45['cast'] = df_ctn45['cast'].astype(str).apply(lambda x: x.split('|')[4])
df_plus4 =df_ctn41.append(df_ctn42).append(df_ctn43).append(df_ctn44).append(df_ctn45)

# %%
df = df_plus0.append(df_plus1,ignore_index = True).append(df_plus2,ignore_index = True).append(df_plus3,ignore_index = True).append(df_plus4,ignore_index = True)
df.shape
# Out:
# (52649, 12)

# %%
df.head(1)
# Out:
#   original_title               cast       director                 keywords  \
# 0        Ronaldo  Cristiano Ronaldo  Anthony Wonke  biography|soccer player
#
#    runtime       genres                               production_companies  \
# 0        0  Documentary  On The Corner Films|We Came, We Saw, We Conque...
#
#   release_date  vote_count  vote_average  profit  cast_counts
# 0      11/9/15          80           6.5     0.0            0

# %%
df_plus4.groupby('original_title').count()
# Out:
#                                                     cast  director  keywords  \
# original_title
# $5 a Day                                               5         5         5
# $9.99                                                  5         5         5
# '71                                                    5         5         5
# (500) Days of Summer                                   5         5         5
# (T)Raumschiff Surprise - Periode 1                     5         5         5
# *batteries not included                                5         5         5
# ...And Justice for All                                 5         5         5
# 1                                                     10        10        10
# 10                                                     5         5         5
# 10 Items or Less                                       5         5         5
# 10 Rillington Place                                    5         5         5
# ...

# %%
df['release_date'].isnull().sum()
# Out:
# 0

# %%
df['month']=df['release_date'].apply(lambda x: x.split('/')[0]) #提取上映月份，并放入新列month中
df.head(3)
# Out:
#         original_title               cast                           director  \
# 0              Ronaldo  Cristiano Ronaldo                      Anthony Wonke
# 1       Monkey Kingdom           Tina Fey  Mark Linfield|Alastair Fothergill
# 2  Sanjay's Super Team                                          Sanjay Patel
#
#                   keywords  runtime                 genres  \
# 0  biography|soccer player        0            Documentary
# 1                                81  Animation|Documentary
# 2                                 7              Animation
#
#                                 production_companies release_date  vote_count  \
# 0  On The Corner Films|We Came, We Saw, We Conque...      11/9/15          80
# 1                                       Disneynature      4/17/15          39
# 2                            Pixar Animation Studios     11/25/15          47
#
#    vote_average        profit  cast_counts month
# 0           6.5  0.000000e+00            0    11
# ...

# %%
total_genres_rows = df['genres'].shape[0]
#计算genres一栏中，每个元素里含有几个”|“
genres_counts = []
for i in range(total_genres_rows):
    num_1 = df['genres'].astype(str).iloc[i].count('|')
    genres_counts.append(num_1)

# %%
set(genres_counts)
# Out:
# {0, 1, 2, 3, 4}

# %%
df['genres_counts'] = genres_counts  #添加一列genres_counts，表示genres中有几个|

# %%
df.head(2)
# Out:
#    original_title               cast                           director  \
# 0         Ronaldo  Cristiano Ronaldo                      Anthony Wonke
# 1  Monkey Kingdom           Tina Fey  Mark Linfield|Alastair Fothergill
#
#                   keywords  runtime                 genres  \
# 0  biography|soccer player        0            Documentary
# 1                                81  Animation|Documentary
#
#                                 production_companies release_date  vote_count  \
# 0  On The Corner Films|We Came, We Saw, We Conque...      11/9/15          80
# 1                                       Disneynature      4/17/15          39
#
#    vote_average        profit  cast_counts month  genres_counts
# 0           6.5  0.000000e+00            0    11              0
# 1           6.3  1.532818e+07            0     4              1

# %%
df_ctn_0 = df.query('genres_counts == 0')
df_plus_0 = df_ctn_0

# %%
df_ctn_1 = df.query('genres_counts == 1')
df_ctn1_1 = df_ctn_1.copy()
df_ctn1_2 = df_ctn_1.copy()
df_ctn1_1['genres'] = df_ctn1_1['genres'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn1_2['genres'] = df_ctn1_2['genres'].astype(str).apply(lambda x: x.split('|')[1])
df_plus_1 =df_ctn1_1.append(df_ctn1_2)

# %%
df_ctn_2 = df.query('genres_counts == 2')
df_ctn2_1 = df_ctn_2.copy()
df_ctn2_2 = df_ctn_2.copy()
df_ctn2_3 = df_ctn_2.copy()
df_ctn2_1['genres'] = df_ctn2_1['genres'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn2_2['genres'] = df_ctn2_2['genres'].astype(str).apply(lambda x: x.split('|')[1])
df_ctn2_3['genres'] = df_ctn2_3['genres'].astype(str).apply(lambda x: x.split('|')[2])
df_plus_2 =df_ctn2_1.append(df_ctn2_2).append(df_ctn2_3)

# %%
df_ctn_3 = df.query('genres_counts == 3')
df_ctn3_1 = df_ctn_3.copy()
df_ctn3_2 = df_ctn_3.copy()
df_ctn3_3 = df_ctn_3.copy()
df_ctn3_4 = df_ctn_3.copy()
df_ctn3_1['genres'] = df_ctn3_1['genres'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn3_2['genres'] = df_ctn3_2['genres'].astype(str).apply(lambda x: x.split('|')[1])
df_ctn3_3['genres'] = df_ctn3_3['genres'].astype(str).apply(lambda x: x.split('|')[2])
df_ctn3_4['genres'] = df_ctn3_4['genres'].astype(str).apply(lambda x: x.split('|')[3])
df_plus_3 =df_ctn3_1.append(df_ctn3_2).append(df_ctn3_3).append(df_ctn3_4)

# %%
df_ctn_4 = df.query('genres_counts == 4')
df_ctn4_1 = df_ctn_4.copy()
df_ctn4_2 = df_ctn_4.copy()
df_ctn4_3 = df_ctn_4.copy()
df_ctn4_4 = df_ctn_4.copy()
df_ctn4_5 = df_ctn_4.copy()
df_ctn4_1['genres'] = df_ctn4_1['genres'].astype(str).apply(lambda x: x.split('|')[0])
df_ctn4_2['genres'] = df_ctn4_2['genres'].astype(str).apply(lambda x: x.split('|')[1])
df_ctn4_3['genres'] = df_ctn4_3['genres'].astype(str).apply(lambda x: x.split('|')[2])
df_ctn4_4['genres'] = df_ctn4_4['genres'].astype(str).apply(lambda x: x.split('|')[3])
df_ctn4_5['genres'] = df_ctn4_5['genres'].astype(str).apply(lambda x: x.split('|')[4])
df_plus_4 =df_ctn4_1.append(df_ctn4_2).append(df_ctn4_3).append(df_ctn4_4).append(df_ctn4_5)

# %%
df = df_plus_0.append(df_plus_1,ignore_index = True).append(df_plus_2,ignore_index = True).append(df_plus_3,ignore_index = True).append(df_plus_4,ignore_index = True)
df.shape
# Out:
# (131879, 14)

# %%
df.head(2)
# Out:
#         original_title               cast       director  \
# 0              Ronaldo  Cristiano Ronaldo  Anthony Wonke
# 1  Sanjay's Super Team                      Sanjay Patel
#
#                   keywords  runtime       genres  \
# 0  biography|soccer player        0  Documentary
# 1                                 7    Animation
#
#                                 production_companies release_date  vote_count  \
# 0  On The Corner Films|We Came, We Saw, We Conque...      11/9/15          80
# 1                            Pixar Animation Studios     11/25/15          47
#
#    vote_average  profit  cast_counts month  genres_counts
# 0           6.5     0.0            0    11              0
# 1           6.9     0.0            0    11              0

# %%
df = df.drop(['cast_counts','genres_counts'],axis=1)
df.head(2)
# Out:
#         original_title               cast       director  \
# 0              Ronaldo  Cristiano Ronaldo  Anthony Wonke
# 1  Sanjay's Super Team                      Sanjay Patel
#
#                   keywords  runtime       genres  \
# 0  biography|soccer player        0  Documentary
# 1                                 7    Animation
#
#                                 production_companies release_date  vote_count  \
# 0  On The Corner Films|We Came, We Saw, We Conque...      11/9/15          80
# 1                            Pixar Animation Studios     11/25/15          47
#
#    vote_average  profit month
# 0           6.5     0.0    11
# 1           6.9     0.0    11

# %%
df.shape
# Out:
# (131879, 12)

# %%
# #计算导演一栏中，每个元素里还有几个”|“
# director_counts = []
# for i in range(df_clean.shape[0]):
#     num_2 = df_clean['director'].astype(str).iloc[i].count('|')
#     director_counts.append(num_2)

# %%
# set(director_counts)

# %%
# df_dir = df_clean[df_clean['director'].str.contains('|')]
# df_dir0 = df_dir.copy()
# df_dir1 = df_dir.copy()

# %%
# df_dir0.head(1)
# Out:
#   original_title               cast       director                 keywords  \
# 0        Ronaldo  Cristiano Ronaldo  Anthony Wonke  biography|soccer player
#
#    runtime       genres                               production_companies  \
# 0        0  Documentary  On The Corner Films|We Came, We Saw, We Conque...
#
#   release_date  vote_count  vote_average  profit  cast_counts month
# 0      11/9/15          80           6.5     0.0            0    11

# %%
# df_dir0['director'] = df_dir0['director'].apply(lambda x:x.split('|')[0])
# df_dir1['director']  = df_dir1['director'].apply(lambda x:x.split('|')[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-119-70fcc5d45b2a> in <module>
#       1 df_dir0['director'] = df_dir0['director'].apply(lambda x:x.split('|')[0])
# ----> 2 df_dir1['director']  = df_dir1['director'].apply(lambda x:x.split('|')[1])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-119-70fcc5d45b2a> in <lambda>(x)
#       1 df_dir0['director'] = df_dir0['director'].apply(lambda x:x.split('|')[0])
# ...

# %%
df_ctn = df[df['cast'].str.contains("|")]

# %%
df1 = df_ctn.copy()
df2 = df_ctn.copy()
df3 = df_ctn.copy()
df4 = df_ctn.copy()
df5 = df_ctn.copy()

# %%
#每个元素以”|“隔开并形成新的行
for i in cast_counts:
    new_rows = pd.DataFrame(columns = ['original_title', 'cast', 'director', 'keywords', 'runtime', 'genres',
                         'production_companies', 'release_date', 'vote_count', 'vote_average','profit'])
    df_plus = pd.DataFrame(columns = ['original_title', 'cast', 'director', 'keywords', 'runtime', 'genres',
                         'production_companies', 'release_date', 'vote_count', 'vote_average','profit'])
    if i ==0:
        df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
        df_plus = df1
    if i == 1:
        df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
        df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
        df_plus =df1.append(df2)
    elif i == 2:
        df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
        df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
        df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
        df_plus =df1.append(df2).append(df3)
    elif i == 3:
        df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
        df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
        df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
        df4[c] = df4[c].astype(str).apply(lambda x: x.split('|')[3])
        df_plus =df1.append(df2).append(df3).append(df4)
    elif i == 4:
        df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
        df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
        df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
        df4[c] = df4[c].astype(str).apply(lambda x: x.split('|')[3])
        df5[c] = df5[c].astype(str).apply(lambda x: x.split('|')[4])
        df_plus = df1.append(df2).append(df3).append(df4).append(df5)
    
    new_rows.append(df_plus)
df = df.append(new_rows, ignore_index =True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-f1a1c2375e71> in <module>
#      24         df_plus =df1.append(df2).append(df3).append(df4)
#      25     elif i == 4:
# ---> 26         df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
#      27         df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
#      28         df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
#
# NameError: name 'c' is not defined

# %%
df.head()
# Out:
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             keywords runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island     124
# 1   future|chase|post-apocalyptic|dystopia|australia     120
# 2  based on novel|revolution|dystopia|sequel|dyst...     119
# 3              android|spaceship|jedi|space opera|3d     136
# ...

# %%
for c in split_columns:
    for i in df[c].iloc[range(total_rows)].count('|'):
        if i ==0:
            df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
        if i == 1:
            df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
            df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
            
        elif i == 2:
            df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
            df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
            df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
            
        elif i == 3:
            df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
            df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
            df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
            df4[c] = df4[c].astype(str).apply(lambda x: x.split('|')[3])
            
        elif i == 4:
            df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
            df2[c] = df2[c].astype(str).apply(lambda x: x.split('|')[1])
            df3[c] = df3[c].astype(str).apply(lambda x: x.split('|')[2])
            df4[c] = df4[c].astype(str).apply(lambda x: x.split('|')[3])
            df5[c] = df5[c].astype(str).apply(lambda x: x.split('|')[4])
#         else:
#             continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-7cfb6d0c04ca> in <module>
#       1 for c in split_columns:
# ----> 2     for i in df[c].iloc[range(total_rows)].count('|'):
#       3         if i ==0:
#       4             df1[c] = df1[c].astype(str).apply(lambda x: x.split('|')[0])
#       5         if i == 1:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in count(self, level)
#    1419
#    1420         if isinstance(level, compat.string_types):
# -> 1421             level = self.index._get_level_number(level)
#    1422
#    1423         lev = self.index.levels[level]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1959
#    1960     def _get_level_number(self, level):
# -> 1961         self._validate_index_level(level)
#    1962         return 0
#    1963
#
# ...
